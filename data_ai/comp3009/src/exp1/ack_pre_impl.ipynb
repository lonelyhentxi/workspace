# %%
from shared.log_service import LogService
from shared.path_service import PathService
from injector import Injector
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
# 全局注入器对服务进行依赖注入
injector = Injector()
# 获取日志服务
log_service:LogService = injector.get(LogService)
path_service:PathService = injector.get(PathService)
# Out:
# 2018-09-30 19:54:39,827 - INFO - [LogService]:LogService initialized.

# %%
rawdf_path = path_service.get_resource("lab1/bank-full.csv")

# %%
rawdf = pd.read_csv(rawdf_path,sep=";")
rawdf.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
(rawdf.columns.get_values())[rawdf.dtypes.get_values()=='object']
rawdf.drop([1],axis=0).head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
# 5   35    management  married   tertiary      no      231     yes   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no
# 5  unknown    5   may       139         1     -1         0  unknown  no

# %%
def get_replacement_parts(rawdf: pd.DataFrame):
    numeric_cols = (rawdf.columns.get_values())[rawdf.dtypes.get_values() != "object"]
    str_cols = (rawdf.columns.get_values())[rawdf.dtypes.get_values() == "object"]
    numeric_means = pd.DataFrame(rawdf.replace('unknown', np.NaN)[numeric_cols].mean()).transpose()
    str_modes = rawdf.replace('unknown', np.NaN)[str_cols].mode()
    return numeric_means, str_modes


def get_replacements(df: pd.DataFrame):
    replaced = pd.concat(list(get_replacement_parts(df)), axis=1, sort=True)
    replaced_dic = dict.fromkeys(replaced.columns.get_values())
    for k in replaced_dic.keys():
        replaced_dic[k] = replaced.loc[0,k]
    return replaced_dic

# %%
numeric_means,str_modes = get_replacement_parts(rawdf)
numeric_means.head()
# Out:
#         age      balance        day   duration  campaign      pdays  previous
# 0  40.93621  1362.272058  15.806419  258.16308  2.763841  40.197828  0.580323

# %%
str_modes.head()
# Out:
#            job  marital  education default housing loan   contact month  \
# 0  blue-collar  married  secondary      no     yes   no  cellular   may
#
#   poutcome   y
# 0  failure  no

# %%
replaced = get_replacements(rawdf)
replaced
# Out:
# {'age': 40.93621021432837,
#  'balance': 1362.2720576850766,
#  'day': 15.80641879188693,
#  'duration': 258.1630797814691,
#  'campaign': 2.763840658246887,
#  'pdays': 40.19782796222158,
#  'previous': 0.5803233726305546,
#  'job': 'blue-collar',
#  'marital': 'married',
#  'education': 'secondary',
#  'default': 'no',
#  'housing': 'yes',
#  'loan': 'no',
#  'contact': 'cellular',
#  'month': 'may',
#  'poutcome': 'failure',
#  'y': 'no'}

# %%
from typing import Collection, Any


def remove_missing(df: pd.DataFrame, targets: Collection[Any]):
    ret_df:pd.DataFrame = df.replace(targets,np.NaN,inplace=False)
    ret_df.fillna(get_replacements(ret_df),inplace=True)
    return ret_df

# %%
missing_removed_df = remove_missing(rawdf,["unknown"])
missing_removed_df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married  secondary      no     1506     yes   no
# 4   33   blue-collar   single  secondary      no        1      no   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular    5   may       261         1     -1         0  failure  no
# 1  cellular    5   may       151         1     -1         0  failure  no
# 2  cellular    5   may        76         1     -1         0  failure  no
# 3  cellular    5   may        92         1     -1         0  failure  no
# 4  cellular    5   may       198         1     -1         0  failure  no

# %%
def discretize(df: pd.DataFrame, column: str, qbins: int):
    ret_df = df.copy()
    ret_df.loc[:,column] = pd.qcut(df[column],qbins)
    return ret_df

# %%
age_discretized_df =  discretize(missing_removed_df, 'age',10)
age_discretized_df.head()
# Out:
#             age           job  marital  education default  balance housing  \
# 0  (56.0, 95.0]    management  married   tertiary      no     2143     yes
# 1  (42.0, 46.0]    technician   single  secondary      no       29     yes
# 2  (32.0, 34.0]  entrepreneur  married  secondary      no        2     yes
# 3  (46.0, 51.0]   blue-collar  married  secondary      no     1506     yes
# 4  (32.0, 34.0]   blue-collar   single  secondary      no        1      no
#
#   loan   contact  day month  duration  campaign  pdays  previous poutcome   y
# 0   no  cellular    5   may       261         1     -1         0  failure  no
# 1   no  cellular    5   may       151         1     -1         0  failure  no
# 2  yes  cellular    5   may        76         1     -1         0  failure  no
# 3   no  cellular    5   may        92         1     -1         0  failure  no
# 4   no  cellular    5   may       198         1     -1         0  failure  no

# %%
balance_discretized_df = discretize(age_discretized_df,"balance",10)
balance_discretized_df.head()
# Out:
#             age           job  marital  education default           balance  \
# 0  (56.0, 95.0]    management  married   tertiary      no  (1859.0, 3574.0]
# 1  (42.0, 46.0]    technician   single  secondary      no     (22.0, 131.0]
# 2  (32.0, 34.0]  entrepreneur  married  secondary      no       (0.0, 22.0]
# 3  (46.0, 51.0]   blue-collar  married  secondary      no  (1126.0, 1859.0]
# 4  (32.0, 34.0]   blue-collar   single  secondary      no       (0.0, 22.0]
#
#   housing loan   contact  day month  duration  campaign  pdays  previous  \
# 0     yes   no  cellular    5   may       261         1     -1         0
# 1     yes   no  cellular    5   may       151         1     -1         0
# 2     yes  yes  cellular    5   may        76         1     -1         0
# 3     yes   no  cellular    5   may        92         1     -1         0
# 4      no   no  cellular    5   may       198         1     -1         0
#
#   poutcome   y
# 0  failure  no
# 1  failure  no
# 2  failure  no
# 3  failure  no
# 4  failure  no

# %%
deduplicated_df = balance_discretized_df.drop_duplicates(inplace=False) 
deduplicated_df.head()
# Out:
#             age           job  marital  education default           balance  \
# 0  (56.0, 95.0]    management  married   tertiary      no  (1859.0, 3574.0]
# 1  (42.0, 46.0]    technician   single  secondary      no     (22.0, 131.0]
# 2  (32.0, 34.0]  entrepreneur  married  secondary      no       (0.0, 22.0]
# 3  (46.0, 51.0]   blue-collar  married  secondary      no  (1126.0, 1859.0]
# 4  (32.0, 34.0]   blue-collar   single  secondary      no       (0.0, 22.0]
#
#   housing loan   contact  day month  duration  campaign  pdays  previous  \
# 0     yes   no  cellular    5   may       261         1     -1         0
# 1     yes   no  cellular    5   may       151         1     -1         0
# 2     yes  yes  cellular    5   may        76         1     -1         0
# 3     yes   no  cellular    5   may        92         1     -1         0
# 4      no   no  cellular    5   may       198         1     -1         0
#
#   poutcome   y
# 0  failure  no
# 1  failure  no
# 2  failure  no
# 3  failure  no
# 4  failure  no

# %%
deduplicated_df.dtypes
# Out:
# age          category
# job            object
# marital        object
# education      object
# default        object
# balance      category
# housing        object
# loan           object
# contact        object
# day             int64
# month          object
# duration        int64
# campaign        int64
# pdays           int64
# previous        int64
# poutcome       object
# y              object
# dtype: object

# %%
import re


def normalize(df: pd.DataFrame):
    ret_df = df.copy()
    
    def converter(x: pd.Series):
        if bool(re.search(r'(int|float)\d*', str(x.dtype), flags=re.I)):
            return (x - np.min(x)) / (np.max(x) - np.min(x))
        return x
    
    return ret_df.apply(converter,axis=0)

# %%
finished_df = normalize(deduplicated_df)
finished_df.head()
# Out:
#             age           job  marital  education default           balance  \
# 0  (56.0, 95.0]    management  married   tertiary      no  (1859.0, 3574.0]
# 1  (42.0, 46.0]    technician   single  secondary      no     (22.0, 131.0]
# 2  (32.0, 34.0]  entrepreneur  married  secondary      no       (0.0, 22.0]
# 3  (46.0, 51.0]   blue-collar  married  secondary      no  (1126.0, 1859.0]
# 4  (32.0, 34.0]   blue-collar   single  secondary      no       (0.0, 22.0]
#
#   housing loan   contact       day month  duration  campaign  pdays  previous  \
# 0     yes   no  cellular  0.133333   may  0.053070       0.0    0.0       0.0
# 1     yes   no  cellular  0.133333   may  0.030704       0.0    0.0       0.0
# 2     yes  yes  cellular  0.133333   may  0.015453       0.0    0.0       0.0
# 3     yes   no  cellular  0.133333   may  0.018707       0.0    0.0       0.0
# 4      no   no  cellular  0.133333   may  0.040260       0.0    0.0       0.0
#
#   poutcome   y
# 0  failure  no
# 1  failure  no
# 2  failure  no
# 3  failure  no
# 4  failure  no
