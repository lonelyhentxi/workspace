# %%
# SZ160110103_周烨恒_第一次实验
import pandas as pd
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer

# %%
# 任务1, 读取文件
df = pd.read_csv('./SW_EpisodeV.txt',sep=" ",encoding="utf-8",names=["index","character","dialogue"],skiprows=1)

# %%
df.head()
# Out:
#    index character                                           dialogue
# 0      1      LUKE  Echo Three to Echo Seven. Han, old buddy, do y...
# 1      2       HAN                    Loud and clear, kid. What's up?
# 2      3      LUKE  Well, I finished my circle. I don't pick up an...
# 3      4       HAN  There isn't enough life on this ice cube to fi...
# 4      5      LUKE  Right. I'll see you shortly. There's a meteori...

# %%
# 任务2, select character, count(index) from df group by character;
df.groupby('character')['index'].count().sort_values(ascending=False).head(10)
# Out:
# character
# HAN         182
# LUKE        128
# LEIA        114
# THREEPIO     92
# LANDO        61
# VADER        56
# YODA         36
# PIETT        23
# CREATURE     21
# BEN          15
# Name: index, dtype: int64

# %%
# 任务3：简化版，不准确
word_counter = Counter()
for i, record in df.iterrows():
     word_counter.update(record['dialogue'].split())
word_counter.most_common(20)
# Out:
# [('the', 222),
#  ('to', 205),
#  ('you', 180),
#  ('I', 175),
#  ('a', 117),
#  ('of', 81),
#  ('is', 68),
#  ('in', 62),
#  ('have', 62),
#  ("I'm", 61),
#  ('be', 60),
#  ('You', 56),
#  ('and', 55),
#  ('for', 53),
#  ("don't", 51),
#  ('not', 51),
#  ('are', 50),
#  ('your', 50),
#  ('it', 48),
#  ('my', 40)]

# %%
# 任务3：使用 counter vectorizer 自带正则分词，加去停词，较准确
vectorizer = CountVectorizer(min_df=1,stop_words="english")
x = vectorizer.fit_transform(df["dialogue"].tolist())
sorted_dict = list(reversed(sorted(vectorizer.vocabulary_.items(),key=lambda x:x[1])))
sorted_dict[0:20]
# Out:
# [('zone', 1170),
#  ('zero', 1169),
#  ('young', 1168),
#  ('yoda', 1167),
#  ('yes', 1166),
#  ('years', 1165),
#  ('yeah', 1164),
#  ('wrong', 1163),
#  ('wouldn', 1162),
#  ('worth', 1161),
#  ('worship', 1160),
#  ('worse', 1159),
#  ('worry', 1158),
#  ('worried', 1157),
#  ('working', 1156),
#  ('work', 1155),
#  ('word', 1154),
#  ('wooly', 1153),
#  ('wookiee', 1152),
#  ('wondering', 1151)]

# %%
# 任务4: 查找前 5 个角色的第一高频词
names = set(df.groupby('character')['index'].count().sort_values(ascending=False).head(5).index.to_list())
lines = []
for i, record in df.iterrows():
    if record['character'] in names:
        lines.append(i)
new_words_dict = pd.DataFrame(zip(x.toarray()[lines,:].sum(axis=0),vectorizer.get_feature_names()),columns=["count","word"])
new_words_dict.sort_values(by="count",ascending=False).head(1)
# Out:
#      count word
# 323     58  don
